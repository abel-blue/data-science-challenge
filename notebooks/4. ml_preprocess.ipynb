# %% [markdown]
# # ML Preprocess
# ## Contents
# - Load Data
# - Data Information
# - Classifying catagorical and numerican datasets
# - Data Wrangling
# - Feature Extraction
# - One Hot Encoding
# - Scale Data
#     - Standard Scaler
#     - Normalize
# - Save Clean Data

# %% [markdown]
# # Load Data

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, LabelEncoder
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
# importing script modules from ../scripts
# Adding scripts path
import sys, os
sys.path.insert(0, '../scripts/')
from data_preProcessing import data_preProcessing_script
from data_manipulator import DataCleaner
from data_exploration import exploration

# %%
df = pd.read_csv("../data/processed_incl_missing.csv")
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#    width height creative_id                            auction_id  \
# 0      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 1      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 2      0      0    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5
# 3      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
# 4      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
#
#                 browser_ts geo_country           site_name  ...  \
# 0  2021-01-01 19:55:20.291    Thailand  www.wuxiaworld.com  ...
# 1  2021-01-01 19:55:20.298    Thailand  www.wuxiaworld.com  ...
# 2  2021-01-05 00:21:39.693    Thailand  www.prachachat.net  ...
# 3  2021-01-06 09:30:44.188    Thailand  www.prachachat.net  ...
# 4  2021-01-06 09:30:45.047    Thailand  www.prachachat.net  ...
#
#    Serving Location(s)             Black/white/audience list included?  \
# 0            Singapore  No black/white/audience list for this campaign
# 1            Singapore  No black/white/audience list for this campaign
# 2            Singapore  No black/white/audience list for this campaign
# 3            Singapore  No black/white/audience list for this campaign
# 4            Singapore  No black/white/audience list for this campaign
#
#   Cost Centre currency Buy Rate (CPE) Volume Agreed Gross Cost/Budget  \
# 0         SGP      USD           0.28      242185.0           67811.8
# 1         SGP      USD           0.28      242185.0           67811.8
# 2         SGP      USD           0.28      242185.0           67811.8
# 3         SGP      USD           0.28      242185.0           67811.8
# 4         SGP      USD           0.28      242185.0           67811.8
#
#   Agency Fee Percentage  Net Cost
# 0          0       15.0  57640.03
# 1          0       15.0  57640.03
# 2          0       15.0  57640.03
# 3          0       15.0  57640.03
# 4          0       15.0  57640.03
#
# [5 rows x 31 columns]

# %% [markdown]
# # Data Information

# %%
preprocess = data_preProcessing_script(df)
preprocess.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99946 entries, 0 to 99945
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   game_key                             99946 non-null  object
#  1   campaign_id                          99946 non-null  object
#  2   type                                 99946 non-null  object
#  3   width                                99946 non-null  int64
#  4   height                               99944 non-null  object
#  5   creative_id                          99946 non-null  object
#  6   auction_id                           99946 non-null  object
#  7   browser_ts                           99946 non-null  object
#  8   geo_country                          99946 non-null  object
#  9   site_name                            99946 non-null  object
#  10  platform_os                          99946 non-null  int64
#  11  device_type                          99946 non-null  object
#  12  browser                              99946 non-null  object
#  13  campaign_name                        99946 non-null  object
#  14  Submission Date                      99946 non-null  object
#  15  Description                          99946 non-null  object
#  16  Campaign Objectives                  99946 non-null  object
#  17  kpis                                 99946 non-null  object
#  18  Placement(s)                         99946 non-null  object
#  19  startdate                            99946 non-null  object
#  20  enddate                              99946 non-null  object
#  21  Serving Location(s)                  99946 non-null  object
#  22  Black/white/audience list included?  99946 non-null  object
#  23  Cost Centre                          99946 non-null  object
#  24  currency                             99946 non-null  object
#  25  Buy Rate (CPE)                       99946 non-null  float64
#  26  Volume Agreed                        99946 non-null  float64
#  27  Gross Cost/Budget                    99946 non-null  float64
#  28  Agency Fee                           99944 non-null  object
#  29  Percentage                           99946 non-null  float64
#  30  Net Cost                             99946 non-null  float64
# dtypes: float64(5), int64(2), object(24)
# memory usage: 23.6+ MB

# %%
print('unique column values')
df.apply(lambda x: len(x.unique())).sort_values(ascending=False).head(33)
# Out:
# unique column values
# browser_ts                             99501
# auction_id                             83071
# site_name                               5779
# creative_id                              312
# game_key                                 180
# campaign_id                               46
# campaign_name                             46
# browser                                   30
# Submission Date                           27
# Description                               27
# startdate                                 22
# enddate                                   21
# Gross Cost/Budget                         17
# Net Cost                                  16
# Campaign Objectives                       15
# Volume Agreed                             15
# Serving Location(s)                       14
# geo_country                               12
# kpis                                       9
# height                                     8
# platform_os                                7
# currency                                   7
# Buy Rate (CPE)                             7
# device_type                                5
# Cost Centre                                5
# Agency Fee                                 4
# Percentage                                 3
# width                                      3
# type                                       3
# Placement(s)                               3
# Black/white/audience list included?        3
# dtype: int64

# %% [markdown]
# # Classifying catagorical and numerical Datasets

# %%
# getting dataframe columns list
cols = df.columns.tolist()

# %%
# numerical values
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['width', 'platform_os', 'Buy Rate (CPE)', 'Volume Agreed',
#        'Gross Cost/Budget', 'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['Description',
#  'Agency Fee',
#  'Placement(s)',
#  'Cost Centre',
#  'browser_ts',
#  'startdate',
#  'height',
#  'device_type',
#  'creative_id',
#  'campaign_id',
#  'Campaign Objectives',
#  'Serving Location(s)',
#  'kpis',
#  'campaign_name',
#  'Black/white/audience list included?',
#  'enddate',
#  'auction_id',
#  'browser',
#  'type',
#  'currency',
#  'geo_country',
#  'Submission Date',
#  'site_name',
#  'game_key']

# %% [markdown]
# # Feature Extraction

# %%
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#    width height creative_id                            auction_id  \
# 0      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 1      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 2      0      0    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5
# 3      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
# 4      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
#
#                 browser_ts geo_country           site_name  ...  \
# 0  2021-01-01 19:55:20.291    Thailand  www.wuxiaworld.com  ...
# 1  2021-01-01 19:55:20.298    Thailand  www.wuxiaworld.com  ...
# 2  2021-01-05 00:21:39.693    Thailand  www.prachachat.net  ...
# 3  2021-01-06 09:30:44.188    Thailand  www.prachachat.net  ...
# 4  2021-01-06 09:30:45.047    Thailand  www.prachachat.net  ...
#
#    Serving Location(s)             Black/white/audience list included?  \
# 0            Singapore  No black/white/audience list for this campaign
# 1            Singapore  No black/white/audience list for this campaign
# 2            Singapore  No black/white/audience list for this campaign
# 3            Singapore  No black/white/audience list for this campaign
# 4            Singapore  No black/white/audience list for this campaign
#
#   Cost Centre currency Buy Rate (CPE) Volume Agreed Gross Cost/Budget  \
# 0         SGP      USD           0.28      242185.0           67811.8
# 1         SGP      USD           0.28      242185.0           67811.8
# 2         SGP      USD           0.28      242185.0           67811.8
# 3         SGP      USD           0.28      242185.0           67811.8
# 4         SGP      USD           0.28      242185.0           67811.8
#
#   Agency Fee Percentage  Net Cost
# 0          0       15.0  57640.03
# 1          0       15.0  57640.03
# 2          0       15.0  57640.03
# 3          0       15.0  57640.03
# 4          0       15.0  57640.03
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['game_key', 'campaign_id', 'type', 'width', 'height', 'creative_id',
#        'auction_id', 'browser_ts', 'geo_country', 'site_name', 'platform_os',
#        'device_type', 'browser', 'campaign_name', 'Submission Date',
#        'Description', 'Campaign Objectives', 'kpis', 'Placement(s)',
#        'startdate', 'enddate', 'Serving Location(s)',
#        'Black/white/audience list included?', 'Cost Centre', 'currency',
#        'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget', 'Agency Fee',
#        'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# columns_with_large_missing_values_extracted_from_json
columns_to_drop = ['game_key', 'campaign_id', 'creative_id', 'auction_id', 'campaign_name', 'height', 'width', 
                   'Submission Date', 'Description', 'Campaign Objectives', 'Black/white/audience list included?', 'Agency Fee']

# %%
df_copy = df.drop(columns_to_drop, axis=1)

# %%
df_copy.head()
# Out:
#          type               browser_ts geo_country           site_name  \
# 0  impression  2021-01-01 19:55:20.291    Thailand  www.wuxiaworld.com
# 1  impression  2021-01-01 19:55:20.298    Thailand  www.wuxiaworld.com
# 2  impression  2021-01-05 00:21:39.693    Thailand  www.prachachat.net
# 3  impression  2021-01-06 09:30:44.188    Thailand  www.prachachat.net
# 4  impression  2021-01-06 09:30:45.047    Thailand  www.prachachat.net
#
#    platform_os device_type                     browser             kpis  \
# 0            6      Mobile                      Chrome  Engagement Rate
# 1            6      Mobile  Mobile Safari UI/WKWebView  Engagement Rate
# 2            6      Mobile               Chrome Mobile  Engagement Rate
# 3            6      Mobile               Mobile Safari  Engagement Rate
# 4            6      Mobile                      Chrome  Engagement Rate
#
#                                         Placement(s)   startdate     enddate  \
# 0  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 1  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 2  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 3  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 4  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
#
#   Serving Location(s) Cost Centre currency  Buy Rate (CPE)  Volume Agreed  \
# 0           Singapore         SGP      USD            0.28       242185.0
# 1           Singapore         SGP      USD            0.28       242185.0
# 2           Singapore         SGP      USD            0.28       242185.0
# 3           Singapore         SGP      USD            0.28       242185.0
# 4           Singapore         SGP      USD            0.28       242185.0
#
#    Gross Cost/Budget  Percentage  Net Cost
# 0            67811.8        15.0  57640.03
# 1            67811.8        15.0  57640.03
# 2            67811.8        15.0  57640.03
# 3            67811.8        15.0  57640.03
# 4            67811.8        15.0  57640.03

# %%
# getting dataframe columns list
cols = df_copy.columns.tolist()

# %%
# numerical values
num_cols = df_copy._get_numeric_data().columns
num_cols
# Out:
# Index(['platform_os', 'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget',
#        'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['enddate',
#  'Placement(s)',
#  'Cost Centre',
#  'geo_country',
#  'site_name',
#  'browser',
#  'device_type',
#  'type',
#  'currency',
#  'Serving Location(s)',
#  'browser_ts',
#  'startdate',
#  'kpis']

# %% [markdown]
# # One Hot Encoding

# %%
df = pd.get_dummies(df_copy, columns=['enddate',
 'Placement(s)',
 'Cost Centre',
 'geo_country',
 'site_name',
 'browser',
 'device_type',
 'type',
 'currency',
 'Serving Location(s)',
 'browser_ts',
 'startdate',
 'kpis'], drop_first= True)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df = pd.get_dummies(df_copy, columns=['enddate',
#       2  'Placement(s)',
#       3  'Cost Centre',
#       4  'geo_country',
#       5  'site_name',
#       6  'browser',
#       7  'device_type',
#       8  'type',
#       9  'currency',
#      10  'Serving Location(s)',
#      11  'browser_ts',
#      12  'startdate',
#      13  'kpis'], drop_first= True)
#      14 df.head(3)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:977, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     973     with_dummies = [data.select_dtypes(exclude=dtypes_to_encode)]
#     975 for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     976     # col is (column_name, column), use just column data here
# --> 977     dummy = _get_dummies_1d(
#     978         col[1],
#     979         prefix=pre,
#     980         prefix_sep=sep,
#     981         dummy_na=dummy_na,
#     982         sparse=sparse,
#     983         drop_first=drop_first,
#     984         dtype=dtype,
#     985     )
#     986     with_dummies.append(dummy)
#     987 result = concat(with_dummies, axis=1)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:1096, in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1092     return concat(sparse_series, axis=1, copy=False)
#    1094 else:
#    1095     # take on axis=1 + transpose to ensure ndarray layout is column-major
# -> 1096     dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=1).T
#    1098     if not dummy_na:
#    1099         # reset NaN GH4446
#    1100         dummy_mat[codes == -1] = 0
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/twodim_base.py:214, in eye(N, M, k, dtype, order, like)
#     212 if M is None:
#     213     M = N
# --> 214 m = zeros((N, M), dtype=dtype, order=order)
#     215 if k >= M:
#     216     return m
#
# MemoryError: Unable to allocate 9.22 GiB for an array with shape (99501, 99501) and data type uint8

# %% [markdown]
# # Scale Data
# ### Standard Scaler
# ### Normalize

# %% [markdown]
# # Save Clean Data
