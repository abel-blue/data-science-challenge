# %% [markdown]
# # ML Preprocess
# ## Contents
# - Load Data
# - Data Information
# - Classifying catagorical and numerican datasets
# - Data Wrangling
# - Label Encoding
# - Scale Data
#     - Standard Scaler
#     - Normalize
# - Save Clean Data (data versions)

# %% [markdown]
# # Load Data

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, LabelEncoder
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
# importing script modules from ../scripts
# Adding scripts path
import sys, os
sys.path.insert(0, '../scripts/')
from data_preProcessing import data_preProcessing_script
from data_manipulator import DataCleaner
from data_exploration import exploration

# %%
df = pd.read_csv("../data/processed_incl_missing.csv")
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#    width height creative_id                            auction_id geo_country  \
# 0      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5    Thailand
# 1      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5    Thailand
# 2      0      0    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5    Thailand
# 3      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f    Thailand
# 4      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f    Thailand
#
#             site_name  platform_os  ... Cost Centre currency Buy Rate (CPE)  \
# 0  www.wuxiaworld.com            6  ...         SGP      USD           0.28
# 1  www.wuxiaworld.com            6  ...         SGP      USD           0.28
# 2  www.prachachat.net            6  ...         SGP      USD           0.28
# 3  www.prachachat.net            6  ...         SGP      USD           0.28
# 4  www.prachachat.net            6  ...         SGP      USD           0.28
#
#   Volume Agreed Gross Cost/Budget Agency Fee Percentage  Net Cost  \
# 0      242185.0           67811.8        0.0       15.0  57640.03
# 1      242185.0           67811.8        0.0       15.0  57640.03
# 2      242185.0           67811.8        0.0       15.0  57640.03
# 3      242185.0           67811.8        0.0       15.0  57640.03
# 4      242185.0           67811.8        0.0       15.0  57640.03
#
#   browser_eng_Date browser_eng_Time
# 0       2021-01-01  19:55:20.291000
# 1       2021-01-01  19:55:20.298000
# 2       2021-01-05  00:21:39.693000
# 3       2021-01-06  09:30:44.188000
# 4       2021-01-06  09:30:45.047000
#
# [5 rows x 32 columns]

# %% [markdown]
# # Data Information

# %%
preprocess = data_preProcessing_script(df)
preprocess.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99946 entries, 0 to 99945
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   game_key                             99946 non-null  object
#  1   campaign_id                          99946 non-null  object
#  2   type                                 99946 non-null  object
#  3   width                                99946 non-null  int64
#  4   height                               99944 non-null  object
#  5   creative_id                          99946 non-null  object
#  6   auction_id                           99946 non-null  object
#  7   geo_country                          99946 non-null  object
#  8   site_name                            99946 non-null  object
#  9   platform_os                          99946 non-null  int64
#  10  device_type                          99946 non-null  object
#  11  browser                              99946 non-null  object
#  12  campaign_name                        99946 non-null  object
#  13  Submission Date                      99946 non-null  object
#  14  Description                          99946 non-null  object
#  15  Campaign Objectives                  99946 non-null  object
#  16  kpis                                 99946 non-null  object
#  17  Placement(s)                         99946 non-null  object
#  18  startdate                            99946 non-null  object
#  19  enddate                              99946 non-null  object
#  20  Serving Location(s)                  99946 non-null  object
#  21  Black/white/audience list included?  99946 non-null  object
#  22  Cost Centre                          99946 non-null  object
#  23  currency                             99946 non-null  object
#  24  Buy Rate (CPE)                       99946 non-null  float64
#  25  Volume Agreed                        99946 non-null  float64
#  26  Gross Cost/Budget                    99946 non-null  float64
#  27  Agency Fee                           99944 non-null  float64
#  28  Percentage                           99946 non-null  float64
#  29  Net Cost                             99946 non-null  float64
#  30  browser_eng_Date                     99946 non-null  object
#  31  browser_eng_Time                     99946 non-null  object
# dtypes: float64(6), int64(2), object(24)
# memory usage: 24.4+ MB

# %%
print('unique column values')
df.apply(lambda x: len(x.unique())).sort_values(ascending=False).head(33)
# Out:
# unique column values
# browser_eng_Time                       99453
# auction_id                             83071
# site_name                               5779
# creative_id                              312
# game_key                                 180
# browser_eng_Date                         160
# campaign_name                             46
# campaign_id                               46
# browser                                   30
# Submission Date                           27
# Description                               27
# startdate                                 22
# enddate                                   21
# Gross Cost/Budget                         17
# Net Cost                                  16
# Volume Agreed                             16
# Campaign Objectives                       15
# Serving Location(s)                       14
# geo_country                               12
# Buy Rate (CPE)                            11
# kpis                                       9
# height                                     8
# currency                                   7
# platform_os                                7
# Cost Centre                                5
# device_type                                5
# Black/white/audience list included?        3
# width                                      3
# Placement(s)                               3
# Percentage                                 3
# type                                       3
# Agency Fee                                 2
# dtype: int64

# %% [markdown]
# # Classifying catagorical and numerical Datasets

# %%
# getting dataframe columns list
cols = df.columns.tolist()

# %%
# numerical values
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['width', 'platform_os', 'Buy Rate (CPE)', 'Volume Agreed',
#        'Gross Cost/Budget', 'Agency Fee', 'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['Serving Location(s)',
#  'browser_eng_Time',
#  'Submission Date',
#  'currency',
#  'height',
#  'enddate',
#  'creative_id',
#  'Placement(s)',
#  'auction_id',
#  'device_type',
#  'site_name',
#  'geo_country',
#  'Description',
#  'type',
#  'campaign_name',
#  'browser_eng_Date',
#  'campaign_id',
#  'browser',
#  'Cost Centre',
#  'Campaign Objectives',
#  'startdate',
#  'Black/white/audience list included?',
#  'game_key',
#  'kpis']

# %% [markdown]
# # Data Wrangling

# %%
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#    width height creative_id                            auction_id geo_country  \
# 0      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5    Thailand
# 1      0      0    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5    Thailand
# 2      0      0    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5    Thailand
# 3      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f    Thailand
# 4      0      0    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f    Thailand
#
#             site_name  platform_os  ... Cost Centre currency Buy Rate (CPE)  \
# 0  www.wuxiaworld.com            6  ...         SGP      USD           0.28
# 1  www.wuxiaworld.com            6  ...         SGP      USD           0.28
# 2  www.prachachat.net            6  ...         SGP      USD           0.28
# 3  www.prachachat.net            6  ...         SGP      USD           0.28
# 4  www.prachachat.net            6  ...         SGP      USD           0.28
#
#   Volume Agreed Gross Cost/Budget Agency Fee Percentage  Net Cost  \
# 0      242185.0           67811.8        0.0       15.0  57640.03
# 1      242185.0           67811.8        0.0       15.0  57640.03
# 2      242185.0           67811.8        0.0       15.0  57640.03
# 3      242185.0           67811.8        0.0       15.0  57640.03
# 4      242185.0           67811.8        0.0       15.0  57640.03
#
#   browser_eng_Date browser_eng_Time
# 0       2021-01-01  19:55:20.291000
# 1       2021-01-01  19:55:20.298000
# 2       2021-01-05  00:21:39.693000
# 3       2021-01-06  09:30:44.188000
# 4       2021-01-06  09:30:45.047000
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['game_key', 'campaign_id', 'type', 'width', 'height', 'creative_id',
#        'auction_id', 'geo_country', 'site_name', 'platform_os', 'device_type',
#        'browser', 'campaign_name', 'Submission Date', 'Description',
#        'Campaign Objectives', 'kpis', 'Placement(s)', 'startdate', 'enddate',
#        'Serving Location(s)', 'Black/white/audience list included?',
#        'Cost Centre', 'currency', 'Buy Rate (CPE)', 'Volume Agreed',
#        'Gross Cost/Budget', 'Agency Fee', 'Percentage', 'Net Cost',
#        'browser_eng_Date', 'browser_eng_Time'],
#       dtype='object')

# %%
# unwanted column for ml model
columns_to_drop = ['game_key', 'campaign_id', 'creative_id', 'auction_id', 'campaign_name', 'height', 'width', 
                   'Submission Date', 'Description', 'Campaign Objectives', 'Black/white/audience list included?', 'Agency Fee']

# %%
df_copy = df.drop(columns_to_drop, axis=1)

# %%
df_copy.head()
# Out:
#          type geo_country           site_name  platform_os device_type  \
# 0  impression    Thailand  www.wuxiaworld.com            6      Mobile
# 1  impression    Thailand  www.wuxiaworld.com            6      Mobile
# 2  impression    Thailand  www.prachachat.net            6      Mobile
# 3  impression    Thailand  www.prachachat.net            6      Mobile
# 4  impression    Thailand  www.prachachat.net            6      Mobile
#
#                       browser             kpis  \
# 0                      Chrome  Engagement Rate
# 1  Mobile Safari UI/WKWebView  Engagement Rate
# 2               Chrome Mobile  Engagement Rate
# 3               Mobile Safari  Engagement Rate
# 4                      Chrome  Engagement Rate
#
#                                         Placement(s)   startdate     enddate  \
# 0  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 1  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 2  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 3  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
# 4  320x480 (Fullscreen mobile / interstitial)\n30...  2021-07-12  2021-09-08
#
#   Serving Location(s) Cost Centre currency  Buy Rate (CPE)  Volume Agreed  \
# 0           Singapore         SGP      USD            0.28       242185.0
# 1           Singapore         SGP      USD            0.28       242185.0
# 2           Singapore         SGP      USD            0.28       242185.0
# 3           Singapore         SGP      USD            0.28       242185.0
# 4           Singapore         SGP      USD            0.28       242185.0
#
#    Gross Cost/Budget  Percentage  Net Cost browser_eng_Date browser_eng_Time
# 0            67811.8        15.0  57640.03       2021-01-01  19:55:20.291000
# 1            67811.8        15.0  57640.03       2021-01-01  19:55:20.298000
# 2            67811.8        15.0  57640.03       2021-01-05  00:21:39.693000
# 3            67811.8        15.0  57640.03       2021-01-06  09:30:44.188000
# 4            67811.8        15.0  57640.03       2021-01-06  09:30:45.047000

# %%
# getting dataframe columns list
cols = df_copy.columns.tolist()

# %%
# numerical values
num_cols = df_copy._get_numeric_data().columns
num_cols
# Out:
# Index(['platform_os', 'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget',
#        'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['device_type',
#  'Serving Location(s)',
#  'browser_eng_Date',
#  'browser',
#  'browser_eng_Time',
#  'Cost Centre',
#  'type',
#  'enddate',
#  'site_name',
#  'geo_country',
#  'startdate',
#  'kpis',
#  'Placement(s)',
#  'currency']

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cols =['enddate',
 'Placement(s)',
 'Cost Centre',
 'geo_country',
 'site_name',
 'browser',
 'device_type',
 'type',
 'currency',
 'Serving Location(s)',
 'browser_eng_Date',
 'browser_eng_Time',
 'startdate',
 'kpis','platform_os']
#
# Encode labels of multiple columns at once
#
df_copy[cols] = df_copy[cols].apply(LabelEncoder().fit_transform)
#
# Print head
#
df_copy.head()
# Out:
#    type  geo_country  site_name  platform_os  device_type  browser  kpis  \
# 0     2            8       5700            5            0        4     6
# 1     2            8       5700            5            0       19     6
# 2     2            8       4805            5            0        5     6
# 3     2            8       4805            5            0       18     6
# 4     2            8       4805            5            0        4     6
#
#    Placement(s)  startdate  enddate  Serving Location(s)  Cost Centre  \
# 0             1         20       19                    7            2
# 1             1         20       19                    7            2
# 2             1         20       19                    7            2
# 3             1         20       19                    7            2
# 4             1         20       19                    7            2
#
#    currency  Buy Rate (CPE)  Volume Agreed  Gross Cost/Budget  Percentage  \
# 0         6            0.28       242185.0            67811.8        15.0
# 1         6            0.28       242185.0            67811.8        15.0
# 2         6            0.28       242185.0            67811.8        15.0
# 3         6            0.28       242185.0            67811.8        15.0
# 4         6            0.28       242185.0            67811.8        15.0
#
#    Net Cost  browser_eng_Date  browser_eng_Time
# 0  57640.03                23             75060
# 1  57640.03                23             75061
# 2  57640.03                27              1544
# 3  57640.03                28             45867
# 4  57640.03                28             45868

# %% [markdown]
# # Scale Data

# %% [markdown]
# ### Standard Scaler

# %%
scaler = DataCleaner(df_copy, deep=True)
normalizer = DataCleaner(df_copy, deep=True)

# %%
cols =['enddate',
 'Placement(s)',
 'Cost Centre',
 'geo_country',
 'site_name',
 'browser',
 'device_type',
 'type',
 'currency',
 'Serving Location(s)',
 'browser_eng_Date',
 'browser_eng_Time',
 'startdate',
 'kpis','platform_os']

# %%
df_cc = df_copy.drop(cols, axis=1)

# %%
df_cc.head()
# Out:
#    Buy Rate (CPE)  Volume Agreed  Gross Cost/Budget  Percentage  Net Cost
# 0            0.28       242185.0            67811.8        15.0  57640.03
# 1            0.28       242185.0            67811.8        15.0  57640.03
# 2            0.28       242185.0            67811.8        15.0  57640.03
# 3            0.28       242185.0            67811.8        15.0  57640.03
# 4            0.28       242185.0            67811.8        15.0  57640.03

# %%
# Using StandardScaler to standardize the all columns
scale_list = df_cc.columns.to_list()
scaler.standardize_columns(scale_list)
# Out:
#        type  geo_country  site_name  platform_os  device_type  browser  kpis  \
# 0         2            8       5700            5            0        4     6
# 1         2            8       5700            5            0       19     6
# 2         2            8       4805            5            0        5     6
# 3         2            8       4805            5            0       18     6
# 4         2            8       4805            5            0        4     6
# ...     ...          ...        ...          ...          ...      ...   ...
# 99941     2            5       5625            4            0       18     6
# 99942     2            5       5625            4            0       18     6
# 99943     2            5       5625            4            0       18     6
# 99944     1            5       5625            4            0       18     6
# 99945     2            5       5625            5            0        5     6
#
#        Placement(s)  startdate  enddate  Serving Location(s)  Cost Centre  \
# 0                 1         20       19                    7            2
# 1                 1         20       19                    7            2
# 2                 1         20       19                    7            2
# 3                 1         20       19                    7            2
# 4                 1         20       19                    7            2
# ...             ...        ...      ...                  ...          ...
# 99941             1         12       10                    7            2
# 99942             1         12       10                    7            2
# 99943             1         12       10                    7            2
# 99944             1         12       10                    7            2
# 99945             1         12       10                    7            2
#
#        currency  Buy Rate (CPE)  Volume Agreed  Gross Cost/Budget  Percentage  \
# 0             6       -1.454603        2.29958          -0.087472    0.968693
# 1             6       -1.454603        2.29958          -0.087472    0.968693
# 2             6       -1.454603        2.29958          -0.087472    0.968693
# 3             6       -1.454603        2.29958          -0.087472    0.968693
# 4             6       -1.454603        2.29958          -0.087472    0.968693
# ...         ...             ...            ...                ...         ...
# 99941         4        2.396858       -0.45197          -0.629410    0.968693
# 99942         4        2.396858       -0.45197          -0.629410    0.968693
# 99943         4        2.396858       -0.45197          -0.629410    0.968693
# 99944         4        2.396858       -0.45197          -0.629410    0.968693
# 99945         4        2.396858       -0.45197          -0.629410    0.968693
#
#        Net Cost  browser_eng_Date  browser_eng_Time
# 0     -0.172359                23             75060
# 1     -0.172359                23             75061
# 2     -0.172359                27              1544
# 3     -0.172359                28             45867
# 4     -0.172359                28             45868
# ...         ...               ...               ...
# 99941 -0.640576                37             65931
# 99942 -0.640576                37             65935
# 99943 -0.640576                37             65938
# 99944 -0.640576                37             65939
# 99945 -0.640576                37             65952
#
# [99946 rows x 20 columns]

# %% [markdown]
# ### Normalize

# %%
normalizer.normalize_column(scale_list)
# Out:
#        type  geo_country  site_name  platform_os  device_type  browser  kpis  \
# 0         2            8       5700            5            0        4     6
# 1         2            8       5700            5            0       19     6
# 2         2            8       4805            5            0        5     6
# 3         2            8       4805            5            0       18     6
# 4         2            8       4805            5            0        4     6
# ...     ...          ...        ...          ...          ...      ...   ...
# 99941     2            5       5625            4            0       18     6
# 99942     2            5       5625            4            0       18     6
# 99943     2            5       5625            4            0       18     6
# 99944     1            5       5625            4            0       18     6
# 99945     2            5       5625            5            0        5     6
#
#        Placement(s)  startdate  enddate  Serving Location(s)  Cost Centre  \
# 0                 1         20       19                    7            2
# 1                 1         20       19                    7            2
# 2                 1         20       19                    7            2
# 3                 1         20       19                    7            2
# 4                 1         20       19                    7            2
# ...             ...        ...      ...                  ...          ...
# 99941             1         12       10                    7            2
# 99942             1         12       10                    7            2
# 99943             1         12       10                    7            2
# 99944             1         12       10                    7            2
# 99945             1         12       10                    7            2
#
#        currency  Buy Rate (CPE)  Volume Agreed  Gross Cost/Budget  Percentage  \
# 0             6        0.000001       0.938628           0.262816    0.000058
# 1             6        0.000001       0.938628           0.262816    0.000058
# 2             6        0.000001       0.938628           0.262816    0.000058
# 3             6        0.000001       0.938628           0.262816    0.000058
# 4             6        0.000001       0.938628           0.262816    0.000058
# ...         ...             ...            ...                ...         ...
# 99941         4        0.000012       0.770678           0.485527    0.000287
# 99942         4        0.000012       0.770678           0.485527    0.000287
# 99943         4        0.000012       0.770678           0.485527    0.000287
# 99944         4        0.000012       0.770678           0.485527    0.000287
# 99945         4        0.000012       0.770678           0.485527    0.000287
#
#        Net Cost  browser_eng_Date  browser_eng_Time
# 0      0.223394                23             75060
# 1      0.223394                23             75061
# 2      0.223394                27              1544
# 3      0.223394                28             45867
# 4      0.223394                28             45868
# ...         ...               ...               ...
# 99941  0.412698                37             65931
# 99942  0.412698                37             65935
# 99943  0.412698                37             65938
# 99944  0.412698                37             65939
# 99945  0.412698                37             65952
#
# [99946 rows x 20 columns]

# %% [markdown]
# # Save Clean Data (data versioned - dvc)

# %%
scaler = DataCleaner(scaler.df)
scaler.save_clean_data('../data/scaled_data.csv')

# %%
normalizer = DataCleaner(normalizer.df)
normalizer.save_clean_data('../data/norm_data.csv')
