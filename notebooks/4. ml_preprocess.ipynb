# %% [markdown]
# # ML Preprocess
# ## Contents
# - Load Data
# - Data Information
# - Classifying catagorical and numerican datasets
# - Data Wrangling
# - Feature Extraction
# - One Hot Encoding
# - Scale Data
#     - Standard Scaler
#     - Normalize
# - Save Clean Data

# %% [markdown]
# # Load Data

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, LabelEncoder
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
# importing script modules from ../scripts
# Adding scripts path
import sys, os
sys.path.insert(0, '../scripts/')
from data_preProcessing import data_preProcessing_script
from data_manipulator import DataCleaner
from data_exploration import exploration

# %%
df = pd.read_csv("../data/processed_incl_missing.csv")
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#   width height creative_id                            auction_id  \
# 0     %      %    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 1     %      %    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 2     %      %    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5
# 3     %      %    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
# 4     %      %    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
#
#                 browser_ts geo_country           site_name  ...  \
# 0  2021-01-01 19:55:20.291    Thailand  www.wuxiaworld.com  ...
# 1  2021-01-01 19:55:20.298    Thailand  www.wuxiaworld.com  ...
# 2  2021-01-05 00:21:39.693    Thailand  www.prachachat.net  ...
# 3  2021-01-06 09:30:44.188    Thailand  www.prachachat.net  ...
# 4  2021-01-06 09:30:45.047    Thailand  www.prachachat.net  ...
#
#    colors_clickthr_green colors_clickthr_blue colors_clickthr_proportion  \
# 0                  109.0                 77.0                   0.418193
# 1                  109.0                 77.0                   0.418193
# 2                  109.0                 77.0                   0.418193
# 3                  109.0                 77.0                   0.418193
# 4                  109.0                 77.0                   0.418193
#
#   colors_clickthr_saturation colors_clickthr_luminosity videosd eng_type  \
# 0                   0.211111                   0.354902     0.0    swipe
# 1                   0.211111                   0.354902     0.0    swipe
# 2                   0.211111                   0.354902     0.0    swipe
# 3                   0.211111                   0.354902     0.0    swipe
# 4                   0.211111                   0.354902     0.0    swipe
#
#   direction adunit_sizex adunit_sizey
# 0        up        600.0        900.0
# 1        up        600.0        900.0
# 2        up        600.0        900.0
# 3        up        600.0        900.0
# 4        up        600.0        900.0
#
# [5 rows x 52 columns]

# %% [markdown]
# # Data Information

# %%
preprocess = data_preProcessing_script(df)
preprocess.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49965 entries, 0 to 49964
# Data columns (total 52 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   game_key                             49965 non-null  object
#  1   campaign_id                          49965 non-null  object
#  2   type                                 49965 non-null  object
#  3   width                                49965 non-null  object
#  4   height                               49965 non-null  object
#  5   creative_id                          49965 non-null  object
#  6   auction_id                           49965 non-null  object
#  7   browser_ts                           49965 non-null  object
#  8   geo_country                          49965 non-null  object
#  9   site_name                            49965 non-null  object
#  10  platform_os                          49965 non-null  int64
#  11  device_type                          49965 non-null  object
#  12  browser                              49965 non-null  object
#  13  campaign_name                        49965 non-null  object
#  14  Submission Date                      49965 non-null  object
#  15  Description                          49965 non-null  object
#  16  Campaign Objectives                  49965 non-null  object
#  17  kpis                                 49965 non-null  object
#  18  Placement(s)                         49965 non-null  object
#  19  startdate                            49965 non-null  object
#  20  enddate                              49965 non-null  object
#  21  Serving Location(s)                  49965 non-null  object
#  22  Black/white/audience list included?  49965 non-null  object
#  23  Cost Centre                          49965 non-null  object
#  24  currency                             49965 non-null  object
#  25  Buy Rate (CPE)                       49965 non-null  float64
#  26  Volume Agreed                        49965 non-null  float64
#  27  Gross Cost/Budget                    49965 non-null  float64
#  28  Agency Fee                           49965 non-null  object
#  29  Percentage                           49965 non-null  float64
#  30  Net Cost                             49965 non-null  float64
#  31  labels_engagement                    49965 non-null  object
#  32  labels_clickthr                      49965 non-null  object
#  33  text_engagement                      49965 non-null  object
#  34  text_clickthr                        49965 non-null  object
#  35  colors_engagement_red                49965 non-null  float64
#  36  colors_engagement_green              49965 non-null  float64
#  37  colors_engagement_blue               49965 non-null  float64
#  38  colors_engagement_proportion         49965 non-null  float64
#  39  colors_engagement_saturation         49965 non-null  float64
#  40  colors_engagement_luminosity         49965 non-null  float64
#  41  colors_clickthr_red                  49965 non-null  float64
#  42  colors_clickthr_green                49965 non-null  float64
#  43  colors_clickthr_blue                 49965 non-null  float64
#  44  colors_clickthr_proportion           49965 non-null  float64
#  45  colors_clickthr_saturation           49965 non-null  float64
#  46  colors_clickthr_luminosity           49965 non-null  float64
#  47  videosd                              49965 non-null  float64
#  48  eng_type                             49965 non-null  object
#  49  direction                            49965 non-null  object
#  50  adunit_sizex                         49965 non-null  float64
#  51  adunit_sizey                         49965 non-null  float64
# dtypes: float64(20), int64(1), object(31)
# memory usage: 19.8+ MB

# %%
print('unique column values')
df.apply(lambda x: len(x.unique())).sort_values(ascending=False).head(33)
# Out:
# unique column values
# browser_ts                             49533
# auction_id                             42216
# site_name                               4030
# creative_id                              260
# game_key                                 155
# campaign_id                               39
# campaign_name                             39
# browser                                   26
# Description                               24
# Submission Date                           24
# startdate                                 20
# enddate                                   18
# Gross Cost/Budget                         15
# Net Cost                                  14
# Campaign Objectives                       13
# Volume Agreed                             13
# Buy Rate (CPE)                            12
# text_clickthr                             11
# labels_engagement                         11
# Serving Location(s)                       11
# labels_clickthr                           11
# geo_country                               10
# text_engagement                           10
# kpis                                       9
# platform_os                                7
# currency                                   5
# height                                     5
# width                                      5
# device_type                                4
# Percentage                                 3
# Cost Centre                                3
# Black/white/audience list included?        3
# Placement(s)                               3
# dtype: int64

# %% [markdown]
# # Classifying catagorical and numerical Datasets

# %%
# getting dataframe columns list
cols = df.columns.tolist()

# %%
# numerical values
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['platform_os', 'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget',
#        'Percentage', 'Net Cost', 'colors_engagement_red',
#        'colors_engagement_green', 'colors_engagement_blue',
#        'colors_engagement_proportion', 'colors_engagement_saturation',
#        'colors_engagement_luminosity', 'colors_clickthr_red',
#        'colors_clickthr_green', 'colors_clickthr_blue',
#        'colors_clickthr_proportion', 'colors_clickthr_saturation',
#        'colors_clickthr_luminosity', 'videosd', 'adunit_sizex',
#        'adunit_sizey'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['eng_type',
#  'enddate',
#  'text_engagement',
#  'startdate',
#  'browser_ts',
#  'Submission Date',
#  'Placement(s)',
#  'Cost Centre',
#  'type',
#  'Campaign Objectives',
#  'auction_id',
#  'site_name',
#  'labels_clickthr',
#  'text_clickthr',
#  'geo_country',
#  'labels_engagement',
#  'direction',
#  'game_key',
#  'kpis',
#  'campaign_id',
#  'device_type',
#  'height',
#  'browser',
#  'Black/white/audience list included?',
#  'Description',
#  'Serving Location(s)',
#  'Agency Fee',
#  'width',
#  'campaign_name',
#  'creative_id',
#  'currency']

# %% [markdown]
# # Feature Extraction

# %%
df.head()
# Out:
#                                             game_key campaign_id        type  \
# 0  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 1  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 2  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 3  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
# 4  adunit-facebook-conversational-commerce-phase-...     l5kk3r3  impression
#
#   width height creative_id                            auction_id  \
# 0     %      %    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 1     %      %    x83byc8a  fd74243f-6606-4830-a0ef-dd12f66ec6f5
# 2     %      %    tf2htrrm  b3af878b-fd1a-4c6f-91a2-4e3670d2fda5
# 3     %      %    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
# 4     %      %    x83byc8a  b7c22590-e784-43cf-874d-a661ad99601f
#
#                 browser_ts geo_country           site_name  ...  \
# 0  2021-01-01 19:55:20.291    Thailand  www.wuxiaworld.com  ...
# 1  2021-01-01 19:55:20.298    Thailand  www.wuxiaworld.com  ...
# 2  2021-01-05 00:21:39.693    Thailand  www.prachachat.net  ...
# 3  2021-01-06 09:30:44.188    Thailand  www.prachachat.net  ...
# 4  2021-01-06 09:30:45.047    Thailand  www.prachachat.net  ...
#
#    colors_clickthr_green colors_clickthr_blue colors_clickthr_proportion  \
# 0                  109.0                 77.0                   0.418193
# 1                  109.0                 77.0                   0.418193
# 2                  109.0                 77.0                   0.418193
# 3                  109.0                 77.0                   0.418193
# 4                  109.0                 77.0                   0.418193
#
#   colors_clickthr_saturation colors_clickthr_luminosity videosd eng_type  \
# 0                   0.211111                   0.354902     0.0    swipe
# 1                   0.211111                   0.354902     0.0    swipe
# 2                   0.211111                   0.354902     0.0    swipe
# 3                   0.211111                   0.354902     0.0    swipe
# 4                   0.211111                   0.354902     0.0    swipe
#
#   direction adunit_sizex adunit_sizey
# 0        up        600.0        900.0
# 1        up        600.0        900.0
# 2        up        600.0        900.0
# 3        up        600.0        900.0
# 4        up        600.0        900.0
#
# [5 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['game_key', 'campaign_id', 'type', 'width', 'height', 'creative_id',
#        'auction_id', 'browser_ts', 'geo_country', 'site_name', 'platform_os',
#        'device_type', 'browser', 'campaign_name', 'Submission Date',
#        'Description', 'Campaign Objectives', 'kpis', 'Placement(s)',
#        'startdate', 'enddate', 'Serving Location(s)',
#        'Black/white/audience list included?', 'Cost Centre', 'currency',
#        'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget', 'Agency Fee',
#        'Percentage', 'Net Cost', 'labels_engagement', 'labels_clickthr',
#        'text_engagement', 'text_clickthr', 'colors_engagement_red',
#        'colors_engagement_green', 'colors_engagement_blue',
#        'colors_engagement_proportion', 'colors_engagement_saturation',
#        'colors_engagement_luminosity', 'colors_clickthr_red',
#        'colors_clickthr_green', 'colors_clickthr_blue',
#        'colors_clickthr_proportion', 'colors_clickthr_saturation',
#        'colors_clickthr_luminosity', 'videosd', 'eng_type', 'direction',
#        'adunit_sizex', 'adunit_sizey'],
#       dtype='object')

# %%
# columns_with_large_missing_values_extracted_from_json
columns_to_drop = ['creative_id','campaign_name','auction_id','campaign_id','creative_id','game_key', 'labels_engagement', 'labels_clickthr', 'text_engagement', 
                           'text_clickthr', 'colors_engagement_red', 'colors_engagement_green', 'colors_engagement_blue', 
                            'colors_engagement_proportion', 'colors_engagement_saturation', 'colors_engagement_luminosity', 
                                                         'colors_clickthr_red', 'colors_clickthr_green', 'colors_clickthr_blue', 
                                                         'colors_clickthr_proportion', 'colors_clickthr_saturation', 
                                                         'colors_clickthr_luminosity',
                           'videosd', 'eng_type', 'direction', 'adunit_sizex', 'adunit_sizey']

# %%
df_copy = df.drop(columns_to_drop, axis=1)

# %%
df_copy.head()
# Out:
#          type width height               browser_ts geo_country  \
# 0  impression     %      %  2021-01-01 19:55:20.291    Thailand
# 1  impression     %      %  2021-01-01 19:55:20.298    Thailand
# 2  impression     %      %  2021-01-05 00:21:39.693    Thailand
# 3  impression     %      %  2021-01-06 09:30:44.188    Thailand
# 4  impression     %      %  2021-01-06 09:30:45.047    Thailand
#
#             site_name  platform_os device_type                     browser  \
# 0  www.wuxiaworld.com            6      Mobile                      Chrome
# 1  www.wuxiaworld.com            6      Mobile  Mobile Safari UI/WKWebView
# 2  www.prachachat.net            6      Mobile               Chrome Mobile
# 3  www.prachachat.net            6      Mobile               Mobile Safari
# 4  www.prachachat.net            6      Mobile                      Chrome
#
#        Submission Date  ... Serving Location(s)  \
# 0  2021-06-18 03:18:00  ...           Singapore
# 1  2021-06-18 03:18:00  ...           Singapore
# 2  2021-06-18 03:18:00  ...           Singapore
# 3  2021-06-18 03:18:00  ...           Singapore
# 4  2021-06-18 03:18:00  ...           Singapore
#
#               Black/white/audience list included? Cost Centre currency  \
# 0  No black/white/audience list for this campaign         SGP      USD
# 1  No black/white/audience list for this campaign         SGP      USD
# 2  No black/white/audience list for this campaign         SGP      USD
# 3  No black/white/audience list for this campaign         SGP      USD
# 4  No black/white/audience list for this campaign         SGP      USD
#
#   Buy Rate (CPE) Volume Agreed Gross Cost/Budget  Agency Fee Percentage  \
# 0           0.28      242185.0           67811.8  Percentage       15.0
# 1           0.28      242185.0           67811.8  Percentage       15.0
# 2           0.28      242185.0           67811.8  Percentage       15.0
# 3           0.28      242185.0           67811.8  Percentage       15.0
# 4           0.28      242185.0           67811.8  Percentage       15.0
#
#    Net Cost
# 0  57640.03
# 1  57640.03
# 2  57640.03
# 3  57640.03
# 4  57640.03
#
# [5 rows x 26 columns]

# %%
# getting dataframe columns list
cols = df_copy.columns.tolist()

# %%
# numerical values
num_cols = df_copy._get_numeric_data().columns
num_cols
# Out:
# Index(['platform_os', 'Buy Rate (CPE)', 'Volume Agreed', 'Gross Cost/Budget',
#        'Percentage', 'Net Cost'],
#       dtype='object')

# %%
# catagorical values
list(set(cols) - set(num_cols))
# Out:
# ['enddate',
#  'startdate',
#  'browser_ts',
#  'Placement(s)',
#  'Submission Date',
#  'Cost Centre',
#  'type',
#  'Campaign Objectives',
#  'site_name',
#  'geo_country',
#  'kpis',
#  'device_type',
#  'height',
#  'browser',
#  'Black/white/audience list included?',
#  'Description',
#  'Serving Location(s)',
#  'Agency Fee',
#  'width',
#  'currency']

# %% [markdown]
# # One Hot Encoding

# %% [markdown]
# # Scale Data
# ### Standard Scaler
# ### Normalize

# %% [markdown]
# # Save Clean Data
